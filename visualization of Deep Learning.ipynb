# %%
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import plot_model

# load a model
model = load_model("./model/NN")
plot_model(model, to_file='./model/model_plot_NN.png', show_shapes=True, show_layer_names=True)

# %%
model = load_model("./model/CNN")
plot_model(model, to_file='./model/model_plot_CNN.png', show_shapes=True, show_layer_names=True)
